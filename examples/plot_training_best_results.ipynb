# %%
# %matplotlib widget

# %%
from csd.global_result_manager import GlobalResultManager

# %% [markdown]
# ## Q1: Does our detector implementation yield better results than Homodyne?
# #### Let's check it out for several modes

# %%
import numpy as np
alpha_init = 0.1
alpha_end = 1.4
number_points_to_plot = 16
alpha_step = (alpha_end - alpha_init) / number_points_to_plot
alphas = list(np.arange(alpha_init, alpha_end, alpha_step))

# %%
GlobalResultManager(testing=False).plot_modes_probs(one_alpha=alphas[8], save_plot=False, interactive_plot=True, best_codebook=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
GlobalResultManager(testing=False).plot_modes_probs(save_plot=False, squeezing=True, best_codebook=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
GlobalResultManager(testing=False).plot_modes_probs(save_plot=False, squeezing=False, non_squeezing=True, best_codebook=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Q2: How does it scale with the number of modes compared to the Homodyne?

# %%
GlobalResultManager(testing=False).plot_modes_probs(one_alpha=alphas[8], save_plot=False, apply_log=True, interactive_plot=True, best_codebook=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
GlobalResultManager(testing=False).plot_modes_probs(save_plot=False, apply_log=True, best_codebook=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Q3: How does the results differ depending on the resources used?

# %%
GlobalResultManager(testing=False).plot_success_probabilities(interactive_plot=True, best_codebook=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
