# %%
from csd import CSD
from csd.typings import MeasuringTypes, CSDConfiguration, Backends
import numpy as np
# Out:
# 2021-10-17 09:24:53.603568: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-10-17 09:24:53.603620: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
alphas = list(np.arange(0.05, 1.55, 0.05))

# %%
csd = CSD(csd_config=CSDConfiguration({
    'steps': 500,
    'cutoff_dim': 10,
    'batch_size': 1000,
}))

# %%
csd.plot_success_probabilities(alphas=alphas)

# %%
results = csd.execute_all_backends_and_measuring_types(
    alphas=alphas,
    backends=[Backends.FOCK,
              Backends.GAUSSIAN],
    measuring_types=[MeasuringTypes.PROBABILITIES]
)
# Out:
# [CSD] 0.0.1|DEBUG|2021-10-17 09:25:55]: Executing One Layer circuit with Backend: fock,  with measuring_type: probabilities and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-17 09:25:55]: Optimizing for alpha: 0.05
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:12]: Optimized for alpha: 0.05 beta: -0.727944866824137 p_succ: 0.5424270947514946
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:12]: _execute_for_one_alpha, took: 17 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:12]: Optimizing for alpha: 0.1
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:33]: Optimized for alpha: 0.1 beta: -0.7716498384339711 p_succ: 0.5833167843564873
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:33]: _execute_for_one_alpha, took: 20 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:33]: Optimizing for alpha: 0.15
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:56]: Optimized for alpha: 0.15 beta: -0.6994507515491505 p_succ: 0.6276138948279089
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:56]: _execute_for_one_alpha, took: 23 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:26:56]: Optimizing for alpha: 0.2
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:12]: Optimized for alpha: 0.2 beta: -0.7240130526708608 p_succ: 0.6664880019710229
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:12]: _execute_for_one_alpha, took: 16 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:12]: Optimizing for alpha: 0.25
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:33]: Optimized for alpha: 0.25 beta: -0.7240979694865118 p_succ: 0.7055747615062292
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:33]: _execute_for_one_alpha, took: 20 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:33]: Optimizing for alpha: 0.3
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:45]: Optimized for alpha: 0.3 beta: -0.7060628034134006 p_succ: 0.7454499591192079
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:45]: _execute_for_one_alpha, took: 12 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:27:45]: Optimizing for alpha: 0.35
# [CSD] 0.0.1|DEBUG|2021-10-17 09:28:10]: Optimized for alpha: 0.35 beta: -0.7282463469928695 p_succ: 0.7782683796834216
# [CSD] 0.0.1|DEBUG|2021-10-17 09:28:10]: _execute_for_one_alpha, took: 24 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:28:10]: Optimizing for alpha: 0.4
# [CSD] 0.0.1|DEBUG|2021-10-17 09:28:46]: Optimized for alpha: 0.4 beta: -0.7560547705950782 p_succ: 0.8079295102879578
# [CSD] 0.0.1|DEBUG|2021-10-17 09:28:46]: _execute_for_one_alpha, took: 36 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:28:46]: Optimizing for alpha: 0.45
# [CSD] 0.0.1|DEBUG|2021-10-17 09:29:09]: Optimized for alpha: 0.45 beta: -0.7390434312036824 p_succ: 0.8417429026362939
# [CSD] 0.0.1|DEBUG|2021-10-17 09:29:09]: _execute_for_one_alpha, took: 23 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:29:09]: Optimizing for alpha: 0.5
# [CSD] 0.0.1|DEBUG|2021-10-17 09:29:37]: Optimized for alpha: 0.5 beta: -0.7628171609997871 p_succ: 0.8666438568612465
# [CSD] 0.0.1|DEBUG|2021-10-17 09:29:37]: _execute_for_one_alpha, took: 27 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:29:37]: Optimizing for alpha: 0.55
# [CSD] 0.0.1|DEBUG|2021-10-17 09:30:08]: Optimized for alpha: 0.55 beta: -0.7825735423418306 p_succ: 0.8896954187006408
# [CSD] 0.0.1|DEBUG|2021-10-17 09:30:08]: _execute_for_one_alpha, took: 31 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:30:08]: Optimizing for alpha: 0.6
# [CSD] 0.0.1|DEBUG|2021-10-17 09:30:39]: Optimized for alpha: 0.6 beta: -0.8032974143393529 p_succ: 0.9100741832525575
# [CSD] 0.0.1|DEBUG|2021-10-17 09:30:39]: _execute_for_one_alpha, took: 31 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:30:39]: Optimizing for alpha: 0.65
# [CSD] 0.0.1|DEBUG|2021-10-17 09:31:19]: Optimized for alpha: 0.65 beta: -0.8279824447996817 p_succ: 0.9274063094785752
# [CSD] 0.0.1|DEBUG|2021-10-17 09:31:19]: _execute_for_one_alpha, took: 39 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:31:19]: Optimizing for alpha: 0.7
# [CSD] 0.0.1|DEBUG|2021-10-17 09:31:49]: Optimized for alpha: 0.7 beta: -0.8423711196560391 p_succ: 0.9440769535652859
# [CSD] 0.0.1|DEBUG|2021-10-17 09:31:49]: _execute_for_one_alpha, took: 30 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:31:49]: Optimizing for alpha: 0.75
# [CSD] 0.0.1|DEBUG|2021-10-17 09:32:20]: Optimized for alpha: 0.75 beta: -0.8671054694146698 p_succ: 0.9569644348628873
# [CSD] 0.0.1|DEBUG|2021-10-17 09:32:20]: _execute_for_one_alpha, took: 30 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:32:20]: Optimizing for alpha: 0.8
# [CSD] 0.0.1|DEBUG|2021-10-17 09:33:06]: Optimized for alpha: 0.8 beta: -0.8930037347766357 p_succ: 0.9677694449392492
# [CSD] 0.0.1|DEBUG|2021-10-17 09:33:06]: _execute_for_one_alpha, took: 45 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:33:06]: Optimizing for alpha: 0.85
# [CSD] 0.0.1|DEBUG|2021-10-17 09:33:43]: Optimized for alpha: 0.85 beta: -0.91735409272126 p_succ: 0.9771968547230981
# [CSD] 0.0.1|DEBUG|2021-10-17 09:33:43]: _execute_for_one_alpha, took: 36 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:33:43]: Optimizing for alpha: 0.9
# [CSD] 0.0.1|DEBUG|2021-10-17 09:34:19]: Optimized for alpha: 0.9 beta: -0.9552013899944015 p_succ: 0.9830250839054662
# [CSD] 0.0.1|DEBUG|2021-10-17 09:34:19]: _execute_for_one_alpha, took: 36 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:34:19]: Optimizing for alpha: 0.95
# [CSD] 0.0.1|DEBUG|2021-10-17 09:35:11]: Optimized for alpha: 0.95 beta: -0.9918591282412782 p_succ: 0.9879697987459181
# [CSD] 0.0.1|DEBUG|2021-10-17 09:35:11]: _execute_for_one_alpha, took: 51 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:35:11]: Optimizing for alpha: 1.0
# [CSD] 0.0.1|DEBUG|2021-10-17 09:36:00]: Optimized for alpha: 1.0 beta: -1.035216318602604 p_succ: 0.991127830739786
# [CSD] 0.0.1|DEBUG|2021-10-17 09:36:00]: _execute_for_one_alpha, took: 48 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:36:00]: Optimizing for alpha: 1.05
# [CSD] 0.0.1|DEBUG|2021-10-17 09:36:38]: Optimized for alpha: 1.05 beta: -1.073652728086008 p_succ: 0.994188957743763
# [CSD] 0.0.1|DEBUG|2021-10-17 09:36:38]: _execute_for_one_alpha, took: 37 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:36:38]: Optimizing for alpha: 1.1
# [CSD] 0.0.1|DEBUG|2021-10-17 09:37:27]: Optimized for alpha: 1.1 beta: -1.1173800988548215 p_succ: 0.9960676426550088
# [CSD] 0.0.1|DEBUG|2021-10-17 09:37:27]: _execute_for_one_alpha, took: 49 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:37:27]: Optimizing for alpha: 1.15
# [CSD] 0.0.1|DEBUG|2021-10-17 09:38:11]: Optimized for alpha: 1.15 beta: -1.1617606584382187 p_succ: 0.9974674951073176
# [CSD] 0.0.1|DEBUG|2021-10-17 09:38:11]: _execute_for_one_alpha, took: 44 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:38:11]: Optimizing for alpha: 1.2
# [CSD] 0.0.1|DEBUG|2021-10-17 09:39:23]: Optimized for alpha: 1.2 beta: -1.2068355554175836 p_succ: 0.9985000533228835
# [CSD] 0.0.1|DEBUG|2021-10-17 09:39:23]: _execute_for_one_alpha, took: 1 minute and 12 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:39:23]: Optimizing for alpha: 1.25
# [CSD] 0.0.1|DEBUG|2021-10-17 09:40:25]: Optimized for alpha: 1.25 beta: -1.2546095363224767 p_succ: 0.9990477540566528
# [CSD] 0.0.1|DEBUG|2021-10-17 09:40:25]: _execute_for_one_alpha, took: 1 minute and 1 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:40:25]: Optimizing for alpha: 1.3
# [CSD] 0.0.1|DEBUG|2021-10-17 09:41:19]: Optimized for alpha: 1.3 beta: -1.3032321781777543 p_succ: 0.9993836341657337
# [CSD] 0.0.1|DEBUG|2021-10-17 09:41:19]: _execute_for_one_alpha, took: 54 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:41:19]: Optimizing for alpha: 1.35
# [CSD] 0.0.1|DEBUG|2021-10-17 09:41:55]: Optimized for alpha: 1.35 beta: -1.3514690914075025 p_succ: 0.9996599545628809
# [CSD] 0.0.1|DEBUG|2021-10-17 09:41:55]: _execute_for_one_alpha, took: 36 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:41:55]: Optimizing for alpha: 1.4
# [CSD] 0.0.1|DEBUG|2021-10-17 09:42:44]: Optimized for alpha: 1.4 beta: -1.4008566314189468 p_succ: 0.9997653359374125
# [CSD] 0.0.1|DEBUG|2021-10-17 09:42:44]: _execute_for_one_alpha, took: 48 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:42:44]: Optimizing for alpha: 1.45
# [CSD] 0.0.1|DEBUG|2021-10-17 09:43:31]: Optimized for alpha: 1.45 beta: -1.4502860083566755 p_succ: 0.999818517385468
# [CSD] 0.0.1|DEBUG|2021-10-17 09:43:32]: _execute_for_one_alpha, took: 47 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:43:32]: Optimizing for alpha: 1.5
# [CSD] 0.0.1|DEBUG|2021-10-17 09:44:14]: Optimized for alpha: 1.5 beta: -1.4997370068637708 p_succ: 0.9998190172960841
# [CSD] 0.0.1|DEBUG|2021-10-17 09:44:14]: _execute_for_one_alpha, took: 42 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:44:14]: execute, took: 18 minutes and 19 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:44:14]: Executing One Layer circuit with Backend: gaussian,  with measuring_type: probabilities and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-17 09:44:14]: Optimizing for alpha: 0.05
# [CSD] 0.0.1|DEBUG|2021-10-17 09:47:47]: Optimized for alpha: 0.05 beta: -0.7076973473658322 p_succ: 0.5428167972603087
# [CSD] 0.0.1|DEBUG|2021-10-17 09:47:47]: _execute_for_one_alpha, took: 3 minutes and 33 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:47:47]: Optimizing for alpha: 0.1
# [CSD] 0.0.1|DEBUG|2021-10-17 09:50:53]: Optimized for alpha: 0.1 beta: -0.7503489055241882 p_succ: 0.5838071539633694
# [CSD] 0.0.1|DEBUG|2021-10-17 09:50:53]: _execute_for_one_alpha, took: 3 minutes and 5 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:50:53]: Optimizing for alpha: 0.15
# [CSD] 0.0.1|DEBUG|2021-10-17 09:54:36]: Optimized for alpha: 0.15 beta: -0.7635179284330348 p_succ: 0.6243137891399154
# [CSD] 0.0.1|DEBUG|2021-10-17 09:54:36]: _execute_for_one_alpha, took: 3 minutes and 43 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:54:36]: Optimizing for alpha: 0.2
# [CSD] 0.0.1|DEBUG|2021-10-17 09:59:16]: Optimized for alpha: 0.2 beta: -0.7094187905730746 p_succ: 0.6676716286648965
# [CSD] 0.0.1|DEBUG|2021-10-17 09:59:16]: _execute_for_one_alpha, took: 4 minutes and 39 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 09:59:16]: Optimizing for alpha: 0.25
# [CSD] 0.0.1|DEBUG|2021-10-17 10:03:08]: Optimized for alpha: 0.25 beta: -0.708924555141902 p_succ: 0.7071538711295853
# [CSD] 0.0.1|DEBUG|2021-10-17 10:03:08]: _execute_for_one_alpha, took: 3 minutes and 51 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:03:08]: Optimizing for alpha: 0.3
# [CSD] 0.0.1|DEBUG|2021-10-17 10:07:12]: Optimized for alpha: 0.3 beta: -0.7384894230481641 p_succ: 0.7414901984719131
# [CSD] 0.0.1|DEBUG|2021-10-17 10:07:12]: _execute_for_one_alpha, took: 4 minutes and 4 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:07:12]: Optimizing for alpha: 0.35
# [CSD] 0.0.1|DEBUG|2021-10-17 10:10:45]: Optimized for alpha: 0.35 beta: -0.718076090669863 p_succ: 0.7797574876586797
# [CSD] 0.0.1|DEBUG|2021-10-17 10:10:45]: _execute_for_one_alpha, took: 3 minutes and 32 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:10:45]: Optimizing for alpha: 0.4
# [CSD] 0.0.1|DEBUG|2021-10-17 10:14:26]: Optimized for alpha: 0.4 beta: -0.7307650612084798 p_succ: 0.8115959146186826
# [CSD] 0.0.1|DEBUG|2021-10-17 10:14:26]: _execute_for_one_alpha, took: 3 minutes and 41 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:14:26]: Optimizing for alpha: 0.45
# [CSD] 0.0.1|DEBUG|2021-10-17 10:17:27]: Optimized for alpha: 0.45 beta: -0.7585264624677144 p_succ: 0.8385448411417926
# [CSD] 0.0.1|DEBUG|2021-10-17 10:17:27]: _execute_for_one_alpha, took: 3 minutes and 0 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:17:27]: Optimizing for alpha: 0.5
# [CSD] 0.0.1|DEBUG|2021-10-17 10:20:16]: Optimized for alpha: 0.5 beta: -0.7758112366014724 p_succ: 0.8645682327219888
# [CSD] 0.0.1|DEBUG|2021-10-17 10:20:16]: _execute_for_one_alpha, took: 2 minutes and 48 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:20:16]: Optimizing for alpha: 0.55
# [CSD] 0.0.1|DEBUG|2021-10-17 10:23:44]: Optimized for alpha: 0.55 beta: -0.7763696072562368 p_succ: 0.8907706749941936
# [CSD] 0.0.1|DEBUG|2021-10-17 10:23:44]: _execute_for_one_alpha, took: 3 minutes and 28 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:23:44]: Optimizing for alpha: 0.6
# [CSD] 0.0.1|DEBUG|2021-10-17 10:26:34]: Optimized for alpha: 0.6 beta: -0.8137839966202323 p_succ: 0.9084594477276825
# [CSD] 0.0.1|DEBUG|2021-10-17 10:26:34]: _execute_for_one_alpha, took: 2 minutes and 49 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:26:34]: Optimizing for alpha: 0.65
# [CSD] 0.0.1|DEBUG|2021-10-17 10:29:32]: Optimized for alpha: 0.65 beta: -0.8196441222410943 p_succ: 0.9287533457502986
# [CSD] 0.0.1|DEBUG|2021-10-17 10:29:32]: _execute_for_one_alpha, took: 2 minutes and 58 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:29:32]: Optimizing for alpha: 0.7
# [CSD] 0.0.1|DEBUG|2021-10-17 10:32:30]: Optimized for alpha: 0.7 beta: -0.8432450776143326 p_succ: 0.943932275303311
# [CSD] 0.0.1|DEBUG|2021-10-17 10:32:30]: _execute_for_one_alpha, took: 2 minutes and 57 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:32:30]: Optimizing for alpha: 0.75
# [CSD] 0.0.1|DEBUG|2021-10-17 10:35:28]: Optimized for alpha: 0.75 beta: -0.8742275822714569 p_succ: 0.955864677226814
# [CSD] 0.0.1|DEBUG|2021-10-17 10:35:28]: _execute_for_one_alpha, took: 2 minutes and 57 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:35:28]: Optimizing for alpha: 0.8
# [CSD] 0.0.1|DEBUG|2021-10-17 10:38:57]: Optimized for alpha: 0.8 beta: -0.9042968928732243 p_succ: 0.9661072138641656
# [CSD] 0.0.1|DEBUG|2021-10-17 10:38:57]: _execute_for_one_alpha, took: 3 minutes and 29 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:38:57]: Optimizing for alpha: 0.85
# [CSD] 0.0.1|DEBUG|2021-10-17 10:42:23]: Optimized for alpha: 0.85 beta: -0.9246954152249238 p_succ: 0.9760060724497157
# [CSD] 0.0.1|DEBUG|2021-10-17 10:42:23]: _execute_for_one_alpha, took: 3 minutes and 25 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:42:23]: Optimizing for alpha: 0.9
# [CSD] 0.0.1|DEBUG|2021-10-17 10:46:02]: Optimized for alpha: 0.9 beta: -0.9555809953168238 p_succ: 0.9829672647349786
# [CSD] 0.0.1|DEBUG|2021-10-17 10:46:02]: _execute_for_one_alpha, took: 3 minutes and 38 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:46:02]: Optimizing for alpha: 0.95
# [CSD] 0.0.1|DEBUG|2021-10-17 10:50:46]: Optimized for alpha: 0.95 beta: -0.9939659940302571 p_succ: 0.9876744525859033
# [CSD] 0.0.1|DEBUG|2021-10-17 10:50:46]: _execute_for_one_alpha, took: 4 minutes and 44 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:50:46]: Optimizing for alpha: 1.0
# [CSD] 0.0.1|DEBUG|2021-10-17 10:54:38]: Optimized for alpha: 1.0 beta: -1.0305075532805938 p_succ: 0.9917266756511949
# [CSD] 0.0.1|DEBUG|2021-10-17 10:54:38]: _execute_for_one_alpha, took: 3 minutes and 52 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:54:38]: Optimizing for alpha: 1.05
# [CSD] 0.0.1|DEBUG|2021-10-17 10:59:27]: Optimized for alpha: 1.05 beta: -1.0754548433136857 p_succ: 0.9939821466110241
# [CSD] 0.0.1|DEBUG|2021-10-17 10:59:27]: _execute_for_one_alpha, took: 4 minutes and 48 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 10:59:27]: Optimizing for alpha: 1.1
# [CSD] 0.0.1|DEBUG|2021-10-17 11:04:20]: Optimized for alpha: 1.1 beta: -1.117647630080041 p_succ: 0.9960402349752983
# [CSD] 0.0.1|DEBUG|2021-10-17 11:04:20]: _execute_for_one_alpha, took: 4 minutes and 53 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:04:20]: Optimizing for alpha: 1.15
# [CSD] 0.0.1|DEBUG|2021-10-17 11:08:41]: Optimized for alpha: 1.15 beta: -1.1619065190082951 p_succ: 0.9974549545320331
# [CSD] 0.0.1|DEBUG|2021-10-17 11:08:41]: _execute_for_one_alpha, took: 4 minutes and 20 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:08:41]: Optimizing for alpha: 1.2
# [CSD] 0.0.1|DEBUG|2021-10-17 11:13:37]: Optimized for alpha: 1.2 beta: -1.207324660382191 p_succ: 0.9984521327077943
# [CSD] 0.0.1|DEBUG|2021-10-17 11:13:37]: _execute_for_one_alpha, took: 4 minutes and 55 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:13:37]: Optimizing for alpha: 1.25
# [CSD] 0.0.1|DEBUG|2021-10-17 11:19:34]: Optimized for alpha: 1.25 beta: -1.254930176884949 p_succ: 0.9990256954155456
# [CSD] 0.0.1|DEBUG|2021-10-17 11:19:34]: _execute_for_one_alpha, took: 5 minutes and 57 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:19:34]: Optimizing for alpha: 1.3
# [CSD] 0.0.1|DEBUG|2021-10-17 11:26:04]: Optimized for alpha: 1.3 beta: -1.3028337821552063 p_succ: 0.9994384640370674
# [CSD] 0.0.1|DEBUG|2021-10-17 11:26:04]: _execute_for_one_alpha, took: 6 minutes and 29 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:26:04]: Optimizing for alpha: 1.35
# [CSD] 0.0.1|DEBUG|2021-10-17 11:30:48]: Optimized for alpha: 1.35 beta: -1.3518254587653158 p_succ: 0.9996605174478099
# [CSD] 0.0.1|DEBUG|2021-10-17 11:30:48]: _execute_for_one_alpha, took: 4 minutes and 44 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:30:48]: Optimizing for alpha: 1.4
# [CSD] 0.0.1|DEBUG|2021-10-17 11:36:07]: Optimized for alpha: 1.4 beta: -1.4010236554472608 p_succ: 0.9998104031687648
# [CSD] 0.0.1|DEBUG|2021-10-17 11:36:07]: _execute_for_one_alpha, took: 5 minutes and 19 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:36:07]: Optimizing for alpha: 1.45
# [CSD] 0.0.1|DEBUG|2021-10-17 11:40:50]: Optimized for alpha: 1.45 beta: -1.4506644714077952 p_succ: 0.9998871218791253
# [CSD] 0.0.1|DEBUG|2021-10-17 11:40:50]: _execute_for_one_alpha, took: 4 minutes and 43 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:40:50]: Optimizing for alpha: 1.5
# [CSD] 0.0.1|DEBUG|2021-10-17 11:45:33]: Optimized for alpha: 1.5 beta: -1.5003438371437257 p_succ: 0.9999405778308067
# [CSD] 0.0.1|DEBUG|2021-10-17 11:45:33]: _execute_for_one_alpha, took: 4 minutes and 42 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:45:33]: execute, took: 2 hours, 1 minute and 18 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-17 11:45:33]: execute_all_backends_and_measuring_types, took: 2 hours, 19 minutes and 38 seconds.

# %%
csd.plot_success_probabilities(measuring_types=[MeasuringTypes.PROBABILITIES])

# %%
results = csd.execute_all_backends_and_measuring_types(
    alphas=alphas,
    measuring_types=[MeasuringTypes.SAMPLING]
)
# Out:
# [CSD] 0.0.1|DEBUG|2021-10-16 06:22:51]: Executing One Layer circuit with Backend: fock,  with measuring_type: sampling and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-16 06:22:51]: Optimizing for alpha: 0.05
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: _execute_for_one_alpha, took: 18 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: Optimized for alpha: 0.05 beta: -1.1292187968676647e-06
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: Optimizing for alpha: 0.7
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: _execute_for_one_alpha, took: 34 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: Optimized for alpha: 0.7 beta: -7.77839472653611e-05
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: Optimizing for alpha: 1.1
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: _execute_for_one_alpha, took: 40 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Optimized for alpha: 1.1 beta: -4.6636522620090635e-08
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: execute, took: 1 minute and 33 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Executing One Layer circuit with Backend: gaussian,  with measuring_type: sampling and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Optimizing for alpha: 0.05
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: _execute_for_one_alpha, took: 3 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: Optimized for alpha: 0.05 beta: 0.0
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: Optimizing for alpha: 0.7
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: _execute_for_one_alpha, took: 1 minute and 38 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: Optimized for alpha: 0.7 beta: -3.113996399150598e-07
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: Optimizing for alpha: 1.1
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: _execute_for_one_alpha, took: 1 minute and 51 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: Optimized for alpha: 1.1 beta: 0.0
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: execute, took: 3 minutes and 33 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: execute_all_backends_and_measuring_types, took: 5 minutes and 7 seconds.

# %%
csd.plot_success_probabilities(measuring_types=[MeasuringTypes.SAMPLING])
