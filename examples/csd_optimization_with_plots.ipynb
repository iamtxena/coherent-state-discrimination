# %%
from csd import CSD
import numpy as np

# %%
alphas = list(np.arange(0.0, 1.1, 0.1))

# %%
csd = CSD()

# %%
results = csd.execute_all_backends_and_measuring_types(alphas=alphas)
# Out:
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:55]: Executing One Layer circuit with Backend: fock,  with measuring_type: probabilities
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:55]: Optimizing for alpha: 0.0
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: '_execute_for_one_alpha' took: 0.6817
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: Optimizing for alpha: 0.1
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: '_execute_for_one_alpha' took: 0.0993
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: Optimizing for alpha: 0.2
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: '_execute_for_one_alpha' took: 0.0552
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: Optimizing for alpha: 0.30000000000000004
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: '_execute_for_one_alpha' took: 0.0783
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: Optimizing for alpha: 0.4
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: '_execute_for_one_alpha' took: 0.0981
# [CSD] 0.0.1|DEBUG|2021-10-12 17:15:56]: Optimizing for alpha: 0.5
# ...

# %%
csd.plot_success_probabilities()
