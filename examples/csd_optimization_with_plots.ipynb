# %%
from csd import CSD
from csd.typings import MeasuringTypes, CSDConfiguration
import numpy as np

# %%
alphas = list(np.arange(0.05, 1.55, 0.05))

# %%
csd = CSD(csd_config=CSDConfiguration({
    'steps': 500,
    'cutoff_dim': 10,
    'batch_size': 30,
}))

# %%
csd.plot_success_probabilities(alphas=alphas)

# %%
results = csd.execute_all_backends_and_measuring_types(
    alphas=alphas,
    measuring_types=[MeasuringTypes.PROBABILITIES]
)
# Out:
# 2021-10-16 16:00:46.172653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.177453: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.177998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.178683: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-16 16:00:46.179248: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.179734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.180192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.469637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.470189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.470635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from[CSD] 0.0.1|DEBUG|2021-10-16 16:00:46]: Executing One Layer circuit with Backend: tf,  with measuring_type: probabilities and cutoff_dim: 10
#  SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 16:00:46.471065: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22093 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# [CSD] 0.0.1|DEBUG|2021-10-16 16:00:46]: Optimizing for alpha: 0.05
# [CSD] 0.0.1|DEBUG|2021-10-16 16:00:55]: Learned displacement value at step 100: -0.5987333059310913
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:02]: Learned displacement value at step 200: -0.8064320683479309
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:09]: Learned displacement value at step 300: -0.7978701591491699
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:16]: Learned displacement value at step 400: -0.8508104085922241
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:23]: Learned displacement value at step 500: -0.8783757090568542
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:23]: Optimized for alpha: 0.05 beta: -0.8783757090568542 p_succ: 0.5380347371101379
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:23]: Optimizing for alpha: 0.1
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:30]: Learned displacement value at step 100: -0.7187674045562744
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:37]: Learned displacement value at step 200: -0.7062814235687256
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:44]: Learned displacement value at step 300: -0.7770023345947266
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:51]: Learned displacement value at step 400: -0.7166066765785217
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:58]: Learned displacement value at step 500: -0.6867672204971313
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:58]: Optimized for alpha: 0.1 beta: -0.6867672204971313 p_succ: 0.6418130099773407
# [CSD] 0.0.1|DEBUG|2021-10-16 16:01:58]: Optimizing for alpha: 0.15
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:05]: Learned displacement value at step 100: -0.7320668697357178
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:12]: Learned displacement value at step 200: -0.7628123164176941
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:18]: Learned displacement value at step 300: -0.6755565404891968
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:25]: Learned displacement value at step 400: -0.7069200873374939
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:32]: Learned displacement value at step 500: -0.7440880537033081
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:32]: Optimized for alpha: 0.15 beta: -0.7440880537033081 p_succ: 0.6058597266674042
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:32]: Optimizing for alpha: 0.2
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:39]: Learned displacement value at step 100: -0.6667017936706543
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:46]: Learned displacement value at step 200: -0.72067791223526
# [CSD] 0.0.1|DEBUG|2021-10-16 16:02:53]: Learned displacement value at step 300: -0.7352374792098999
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:00]: Learned displacement value at step 400: -0.7370705604553223
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:07]: Learned displacement value at step 500: -0.7428436279296875
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:07]: Optimized for alpha: 0.2 beta: -0.7428436279296875 p_succ: 0.6668838262557983
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:07]: Optimizing for alpha: 0.25
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:14]: Learned displacement value at step 100: -0.7223724126815796
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:21]: Learned displacement value at step 200: -0.7388817667961121
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:28]: Learned displacement value at step 300: -0.7599632143974304
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:35]: Learned displacement value at step 400: -0.750665009021759
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:42]: Learned displacement value at step 500: -0.7410109043121338
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:42]: Optimized for alpha: 0.25 beta: -0.7410109043121338 p_succ: 0.7218824028968811
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:42]: Optimizing for alpha: 0.3
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:49]: Learned displacement value at step 100: -0.7142168879508972
# [CSD] 0.0.1|DEBUG|2021-10-16 16:03:56]: Learned displacement value at step 200: -0.7120869159698486
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:03]: Learned displacement value at step 300: -0.7255265116691589
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:09]: Learned displacement value at step 400: -0.7129401564598083
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:16]: Learned displacement value at step 500: -0.6916426420211792
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:16]: Optimized for alpha: 0.3 beta: -0.6916426420211792 p_succ: 0.7341947257518768
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:16]: Optimizing for alpha: 0.35
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:23]: Learned displacement value at step 100: -0.7433491349220276
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:30]: Learned displacement value at step 200: -0.727529764175415
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:38]: Learned displacement value at step 300: -0.714057981967926
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:44]: Learned displacement value at step 400: -0.7331994771957397
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:51]: Learned displacement value at step 500: -0.7561765909194946
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:51]: Optimized for alpha: 0.35 beta: -0.7561765909194946 p_succ: 0.7533672899007797
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:51]: Optimizing for alpha: 0.4
# [CSD] 0.0.1|DEBUG|2021-10-16 16:04:58]: Learned displacement value at step 100: -0.7353578209877014
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:05]: Learned displacement value at step 200: -0.7354208827018738
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:12]: Learned displacement value at step 300: -0.694392740726471
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:19]: Learned displacement value at step 400: -0.7731099724769592
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:26]: Learned displacement value at step 500: -0.7030869722366333
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:26]: Optimized for alpha: 0.4 beta: -0.7030869722366333 p_succ: 0.8008183985948563
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:26]: Optimizing for alpha: 0.45
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:34]: Learned displacement value at step 100: -0.7426741719245911
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:40]: Learned displacement value at step 200: -0.7878598570823669
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:47]: Learned displacement value at step 300: -0.7794807553291321
# [CSD] 0.0.1|DEBUG|2021-10-16 16:05:54]: Learned displacement value at step 400: -0.7505473494529724
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:01]: Learned displacement value at step 500: -0.7454788684844971
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:01]: Optimized for alpha: 0.45 beta: -0.7454788684844971 p_succ: 0.8537213057279587
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:01]: Optimizing for alpha: 0.5
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:08]: Learned displacement value at step 100: -0.7869316339492798
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:15]: Learned displacement value at step 200: -0.7871045470237732
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:22]: Learned displacement value at step 300: -0.7687312960624695
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:29]: Learned displacement value at step 400: -0.761185884475708
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:36]: Learned displacement value at step 500: -0.7833520770072937
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:36]: Optimized for alpha: 0.5 beta: -0.7833520770072937 p_succ: 0.8574330806732178
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:36]: Optimizing for alpha: 0.55
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:42]: Learned displacement value at step 100: -0.776144802570343
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:49]: Learned displacement value at step 200: -0.7765909433364868
# [CSD] 0.0.1|DEBUG|2021-10-16 16:06:56]: Learned displacement value at step 300: -0.7862581610679626
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:03]: Learned displacement value at step 400: -0.7888787984848022
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:10]: Learned displacement value at step 500: -0.7750787138938904
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:10]: Optimized for alpha: 0.55 beta: -0.7750787138938904 p_succ: 0.9129991829395294
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:10]: Optimizing for alpha: 0.6
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:17]: Learned displacement value at step 100: -0.8148999214172363
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:24]: Learned displacement value at step 200: -0.8108735680580139
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:31]: Learned displacement value at step 300: -0.7992143630981445
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:38]: Learned displacement value at step 400: -0.7908258438110352
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:45]: Learned displacement value at step 500: -0.8186660408973694
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:45]: Optimized for alpha: 0.6 beta: -0.8186660408973694 p_succ: 0.9157901778817177
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:45]: Optimizing for alpha: 0.65
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:52]: Learned displacement value at step 100: -0.8344793915748596
# [CSD] 0.0.1|DEBUG|2021-10-16 16:07:59]: Learned displacement value at step 200: -0.8467192053794861
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:06]: Learned displacement value at step 300: -0.8253165483474731
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:13]: Learned displacement value at step 400: -0.8389573097229004
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:20]: Learned displacement value at step 500: -0.8326880931854248
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:20]: Optimized for alpha: 0.65 beta: -0.8326880931854248 p_succ: 0.9307125061750412
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:20]: Optimizing for alpha: 0.7
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:27]: Learned displacement value at step 100: -0.8498049974441528
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:34]: Learned displacement value at step 200: -0.8423193693161011
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:41]: Learned displacement value at step 300: -0.8583431839942932
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:48]: Learned displacement value at step 400: -0.8370043039321899
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:54]: Learned displacement value at step 500: -0.8491892218589783
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:54]: Optimized for alpha: 0.7 beta: -0.8491892218589783 p_succ: 0.9459301121532917
# [CSD] 0.0.1|DEBUG|2021-10-16 16:08:54]: Optimizing for alpha: 0.75
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:02]: Learned displacement value at step 100: -0.8787439465522766
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:08]: Learned displacement value at step 200: -0.8583205938339233
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:15]: Learned displacement value at step 300: -0.8778512477874756
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:22]: Learned displacement value at step 400: -0.8749796748161316
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:29]: Learned displacement value at step 500: -0.8833098411560059
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:29]: Optimized for alpha: 0.75 beta: -0.8833098411560059 p_succ: 0.9530030824244022
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:29]: Optimizing for alpha: 0.8
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:36]: Learned displacement value at step 100: -0.9089986681938171
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:43]: Learned displacement value at step 200: -0.8859540224075317
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:50]: Learned displacement value at step 300: -0.8840372562408447
# [CSD] 0.0.1|DEBUG|2021-10-16 16:09:57]: Learned displacement value at step 400: -0.8978806138038635
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:03]: Learned displacement value at step 500: -0.8962854743003845
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:03]: Optimized for alpha: 0.8 beta: -0.8962854743003845 p_succ: 0.9624669067561626
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:03]: Optimizing for alpha: 0.85
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:10]: Learned displacement value at step 100: -0.9227892160415649
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:17]: Learned displacement value at step 200: -0.9333409667015076
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:24]: Learned displacement value at step 300: -0.9342237114906311
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:31]: Learned displacement value at step 400: -0.9049383401870728
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:38]: Learned displacement value at step 500: -0.9376004934310913
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:38]: Optimized for alpha: 0.85 beta: -0.9376004934310913 p_succ: 0.9779099263250828
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:38]: Optimizing for alpha: 0.9
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:45]: Learned displacement value at step 100: -0.9614721536636353
# [CSD] 0.0.1|DEBUG|2021-10-16 16:10:53]: Learned displacement value at step 200: -0.9617771506309509
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:00]: Learned displacement value at step 300: -0.9534916281700134
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:07]: Learned displacement value at step 400: -0.9594892263412476
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:14]: Learned displacement value at step 500: -0.9428577423095703
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:14]: Optimized for alpha: 0.9 beta: -0.9428577423095703 p_succ: 0.9823352862149477
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:14]: Optimizing for alpha: 0.95
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:21]: Learned displacement value at step 100: -0.9983451962471008
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:28]: Learned displacement value at step 200: -0.9923741221427917
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:35]: Learned displacement value at step 300: -0.991294264793396
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:42]: Learned displacement value at step 400: -0.9944097399711609
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:49]: Learned displacement value at step 500: -0.9861093759536743
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:49]: Optimized for alpha: 0.95 beta: -0.9861093759536743 p_succ: 0.9927191617898643
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:49]: Optimizing for alpha: 1.0
# [CSD] 0.0.1|DEBUG|2021-10-16 16:11:56]: Learned displacement value at step 100: -1.0227223634719849
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:03]: Learned displacement value at step 200: -1.023218035697937
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:10]: Learned displacement value at step 300: -1.034956693649292
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:17]: Learned displacement value at step 400: -1.0265307426452637
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:24]: Learned displacement value at step 500: -1.03208589553833
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:24]: Optimized for alpha: 1.0 beta: -1.03208589553833 p_succ: 0.9919381542131305
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:24]: Optimizing for alpha: 1.05
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:31]: Learned displacement value at step 100: -1.0676968097686768
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:38]: Learned displacement value at step 200: -1.0771805047988892
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:45]: Learned displacement value at step 300: -1.0862034559249878
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:52]: Learned displacement value at step 400: -1.0735328197479248
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:59]: Learned displacement value at step 500: -1.0721468925476074
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:59]: Optimized for alpha: 1.05 beta: -1.0721468925476074 p_succ: 0.9945724699646235
# [CSD] 0.0.1|DEBUG|2021-10-16 16:12:59]: Optimizing for alpha: 1.1
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:06]: Learned displacement value at step 100: -1.1178219318389893
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:13]: Learned displacement value at step 200: -1.1177394390106201
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:20]: Learned displacement value at step 300: -1.1174447536468506
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:27]: Learned displacement value at step 400: -1.1175580024719238
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:34]: Learned displacement value at step 500: -1.1160175800323486
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:34]: Optimized for alpha: 1.1 beta: -1.1160175800323486 p_succ: 0.9961865169461817
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:34]: Optimizing for alpha: 1.15
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:41]: Learned displacement value at step 100: -1.1590226888656616
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:48]: Learned displacement value at step 200: -1.1581130027770996
# [CSD] 0.0.1|DEBUG|2021-10-16 16:13:55]: Learned displacement value at step 300: -1.1651015281677246
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:02]: Learned displacement value at step 400: -1.1629317998886108
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:09]: Learned displacement value at step 500: -1.1647577285766602
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:09]: Optimized for alpha: 1.15 beta: -1.1647577285766602 p_succ: 0.9978338878136128
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:09]: Optimizing for alpha: 1.2
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:16]: Learned displacement value at step 100: -1.2062150239944458
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:23]: Learned displacement value at step 200: -1.2073534727096558
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:30]: Learned displacement value at step 300: -1.2066106796264648
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:38]: Learned displacement value at step 400: -1.2075139284133911
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:45]: Learned displacement value at step 500: -1.2063190937042236
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:45]: Optimized for alpha: 1.2 beta: -1.2063190937042236 p_succ: 0.9986490510636941
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:45]: Optimizing for alpha: 1.25
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:52]: Learned displacement value at step 100: -1.2551440000534058
# [CSD] 0.0.1|DEBUG|2021-10-16 16:14:59]: Learned displacement value at step 200: -1.2578442096710205
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:06]: Learned displacement value at step 300: -1.2556562423706055
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:13]: Learned displacement value at step 400: -1.255566120147705
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:19]: Learned displacement value at step 500: -1.2566620111465454
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:19]: Optimized for alpha: 1.25 beta: -1.2566620111465454 p_succ: 0.9990989930811338
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:19]: Optimizing for alpha: 1.3
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:26]: Learned displacement value at step 100: -1.3026379346847534
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:33]: Learned displacement value at step 200: -1.3041380643844604
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:40]: Learned displacement value at step 300: -1.3032879829406738
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:47]: Learned displacement value at step 400: -1.302281379699707
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:54]: Learned displacement value at step 500: -1.3034446239471436
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:54]: Optimized for alpha: 1.3 beta: -1.3034446239471436 p_succ: 0.9992660667048767
# [CSD] 0.0.1|DEBUG|2021-10-16 16:15:54]: Optimizing for alpha: 1.35
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:01]: Learned displacement value at step 100: -1.3519350290298462
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:08]: Learned displacement value at step 200: -1.3513565063476562
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:15]: Learned displacement value at step 300: -1.3524415493011475
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:23]: Learned displacement value at step 400: -1.3504468202590942
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:30]: Learned displacement value at step 500: -1.3517345190048218
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:30]: Optimized for alpha: 1.35 beta: -1.3517345190048218 p_succ: 0.9996181478491053
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:30]: Optimizing for alpha: 1.4
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:37]: Learned displacement value at step 100: -1.4012120962142944
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:44]: Learned displacement value at step 200: -1.4007188081741333
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:51]: Learned displacement value at step 300: -1.4002736806869507
# [CSD] 0.0.1|DEBUG|2021-10-16 16:16:58]: Learned displacement value at step 400: -1.4008170366287231
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:05]: Learned displacement value at step 500: -1.4013241529464722
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:05]: Optimized for alpha: 1.4 beta: -1.4013241529464722 p_succ: 0.9997337785898708
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:05]: Optimizing for alpha: 1.45
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:12]: Learned displacement value at step 100: -1.4504555463790894
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:18]: Learned displacement value at step 200: -1.450264811515808
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:25]: Learned displacement value at step 300: -1.4505119323730469
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:32]: Learned displacement value at step 400: -1.449970006942749
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:39]: Learned displacement value at step 500: -1.4504642486572266
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:39]: Optimized for alpha: 1.45 beta: -1.4504642486572266 p_succ: 0.9998194464133121
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:39]: Optimizing for alpha: 1.5
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:46]: Learned displacement value at step 100: -1.4997825622558594
# [CSD] 0.0.1|DEBUG|2021-10-16 16:17:53]: Learned displacement value at step 200: -1.499979853630066
# [CSD] 0.0.1|DEBUG|2021-10-16 16:18:00]: Learned displacement value at step 300: -1.4997915029525757
# [CSD] 0.0.1|DEBUG|2021-10-16 16:18:08]: Learned displacement value at step 400: -1.499603033065796
# [CSD] 0.0.1|DEBUG|2021-10-16 16:18:14]: Learned displacement value at step 500: -1.499800682067871
# [CSD] 0.0.1|DEBUG|2021-10-16 16:18:14]: Optimized for alpha: 1.5 beta: -1.499800682067871 p_succ: 0.9998383602796821
# [CSD] 0.0.1|DEBUG|2021-10-16 16:18:14]: execute, took: 17 minutes and 28 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 16:18:14]: execute_all_backends_and_measuring_types, took: 17 minutes and 28 seconds.

# %%
csd.plot_success_probabilities(measuring_types=[MeasuringTypes.PROBABILITIES])

# %%
results = csd.execute_all_backends_and_measuring_types(
    alphas=alphas,
    measuring_types=[MeasuringTypes.SAMPLING]
)
# Out:
# [CSD] 0.0.1|DEBUG|2021-10-16 06:22:51]: Executing One Layer circuit with Backend: fock,  with measuring_type: sampling and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-16 06:22:51]: Optimizing for alpha: 0.05
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: _execute_for_one_alpha, took: 18 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: Optimized for alpha: 0.05 beta: -1.1292187968676647e-06
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: Optimizing for alpha: 0.7
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: _execute_for_one_alpha, took: 34 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: Optimized for alpha: 0.7 beta: -7.77839472653611e-05
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: Optimizing for alpha: 1.1
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: _execute_for_one_alpha, took: 40 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Optimized for alpha: 1.1 beta: -4.6636522620090635e-08
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: execute, took: 1 minute and 33 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Executing One Layer circuit with Backend: gaussian,  with measuring_type: sampling and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Optimizing for alpha: 0.05
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: _execute_for_one_alpha, took: 3 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: Optimized for alpha: 0.05 beta: 0.0
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: Optimizing for alpha: 0.7
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: _execute_for_one_alpha, took: 1 minute and 38 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: Optimized for alpha: 0.7 beta: -3.113996399150598e-07
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: Optimizing for alpha: 1.1
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: _execute_for_one_alpha, took: 1 minute and 51 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: Optimized for alpha: 1.1 beta: 0.0
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: execute, took: 3 minutes and 33 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: execute_all_backends_and_measuring_types, took: 5 minutes and 7 seconds.

# %%
csd.plot_success_probabilities(measuring_types=[MeasuringTypes.SAMPLING])
