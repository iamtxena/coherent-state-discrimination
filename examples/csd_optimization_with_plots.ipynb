# %%
from csd import CSD
from csd.typings.typing import MeasuringTypes, CSDConfiguration, Backends
import numpy as np

# %%
alphas = list(np.arange(0.05, 1.55, 0.05))

# %%
csd = CSD(csd_config=CSDConfiguration({
    'steps': 100,
    'cutoff_dim': 10,
    'batch_size': 10,
    'architecture': {
        'displacement': True,
        'squeezing': False,
    },
    'save_results': False,
    'save_plots': False
}))

# %%
results = csd.execute_all_backends_and_measuring_types(
    alphas=alphas,
    backends=[Backends.TENSORFLOW],
    measuring_types=[MeasuringTypes.PROBABILITIES]
)
# Out:
# 2021-10-17 18:33:25.830774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:25.835728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:25.836235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:25.837004: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-17 18:33:25.837502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:25.838049: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:25.838521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:26.141536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:26.142084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:26.142622: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-17 18:33:26.143056: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22132 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# [CSD] 0.0.1|DEBUG|2021-10-17 18:33:26]: Executing One Layer circuit with Backend: tf,  with measuring_type: probabilities and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-17 18:33:26]: Optimizing for alpha: 0.05
# params: [<tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.1>]
# params: <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.1>
# loss: 0.6960200071334839
# gradients: [None]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1631218/3183180198.py in <module>
# ----> 1 results = csd.execute_all_backends_and_measuring_types(
#       2     alphas=alphas,
#       3     backends=[Backends.TENSORFLOW],
#       4     measuring_types=[MeasuringTypes.PROBABILITIES]
#       5 )
#
# ~/sandbox/coherent-state-discrimination/src/csd/util.py in wrap(*args, **kw)
#      39     def wrap(*args, **kw):
#      40         ts = time()
# ---> 41         result = f(*args, **kw)
#      42         te = time()
#      43         # logger.debug('func:%r args:[%r, %r] took: %2.4f sec' % (f.__name__, args, kw, te - ts))
#
# ~/sandbox/coherent-state-discrimination/src/csd/csd.py in execute_all_backends_and_measuring_types(self, alphas, backends, measuring_types)
#     361
#     362         if required_probability_execution:
# --> 363             self._probability_results = self._execute_with_given_backends(alphas=alphas,
#     364                                                                           backends=backends,
#     365                                                                           measuring_type=MeasuringTypes.PROBABILITIES)
#
# ~/sandbox/coherent-state-discrimination/src/csd/csd.py in _execute_with_given_backends(self, alphas, backends, measuring_type)
#     376                                      measuring_type: MeasuringTypes) -> List[ResultExecution]:
#     377
# --> 378         return [self.execute(configuration=RunConfiguration({
#     379             'alphas': alphas,
#     380             'backend': backend,
#
# ~/sandbox/coherent-state-discrimination/src/csd/csd.py in <listcomp>(.0)
#     376                                      measuring_type: MeasuringTypes) -> List[ResultExecution]:
#     377
# --> 378         return [self.execute(configuration=RunConfiguration({
#     379             'alphas': alphas,
#     380             'backend': backend,
#
# ~/sandbox/coherent-state-discrimination/src/csd/util.py in wrap(*args, **kw)
#      39     def wrap(*args, **kw):
#      40         ts = time()
# ---> 41         result = f(*args, **kw)
#      42         te = time()
#      43         # logger.debug('func:%r args:[%r, %r] took: %2.4f sec' % (f.__name__, args, kw, te - ts))
#
# ~/sandbox/coherent-state-discrimination/src/csd/csd.py in execute(self, configuration)
#     220
#     221         for sample_alpha in self._alphas:
# --> 222             self._execute_for_one_alpha(learning_steps, optimization, result, sample_alpha)
#     223
#     224         self._save_results_to_file(result)
#
# ~/sandbox/coherent-state-discrimination/src/csd/util.py in wrap(*args, **kw)
#      39     def wrap(*args, **kw):
#      40         ts = time()
# ---> 41         result = f(*args, **kw)
#      42         te = time()
#      43         # logger.debug('func:%r args:[%r, %r] took: %2.4f sec' % (f.__name__, args, kw, te - ts))
#
# ~/sandbox/coherent-state-discrimination/src/csd/csd.py in _execute_for_one_alpha(self, learning_steps, optimization, result, sample_alpha)
#     245
#     246         for step in range(learning_steps):
# --> 247             optimized_parameters = self._execute_for_one_alpha_and_step(batch_size=self._batch_size,
#     248                                                                         optimization=optimization)
#     249             self._print_opimized_parameters(step, optimized_parameters)
#
# ~/sandbox/coherent-state-discrimination/src/csd/csd.py in _execute_for_one_alpha_and_step(self, batch_size, optimization)
#     310
#     311         self._batch = self._create_random_batch(batch_size=batch_size, alpha_value=self._alpha_value)
# --> 312         optimized_result = optimization.optimize(cost_function=self._cost_function)
#     313         logger.debug(f'optimized_result: {optimized_result}')
#     314         return optimized_result
#
# ~/sandbox/coherent-state-discrimination/src/csd/optimize.py in optimize(self, cost_function)
#      20         if self._optimizer is None:
#      21             raise ValueError("optimizer not initilized")
# ---> 22         return self._optimizer.optimize(cost_function=cost_function)
#
# ~/sandbox/coherent-state-discrimination/src/csd/optimizers/tf.py in optimize(self, cost_function)
#      25         gradients = tape.gradient(loss, [self._beta])
#      26         print(f'gradients: {gradients}')
# ---> 27         self._opt.apply_gradients(zip(gradients, [self._beta]))
#      28         return [param.numpy() for param in [self._beta]]
#
# ~/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     620       RuntimeError: If called in a cross-replica context.
#     621     """
# --> 622     grads_and_vars = optimizer_utils.filter_empty_gradients(grads_and_vars)
#     623     var_list = [v for (_, v) in grads_and_vars]
#     624
#
# ~/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/keras/optimizer_v2/utils.py in filter_empty_gradients(grads_and_vars)
#      70
#      71   if not filtered:
# ---> 72     raise ValueError("No gradients provided for any variable: %s." %
#      73                      ([v.name for _, v in grads_and_vars],))
#      74   if vars_with_empty_grads:
#
# ValueError: No gradients provided for any variable: ['Variable:0'].

# %%
csd.plot_success_probabilities(measuring_types=[MeasuringTypes.PROBABILITIES])

# %%
csd.plot_success_probabilities(measuring_types=[MeasuringTypes.PROBABILITIES])

# %%
results = csd.execute_all_backends_and_measuring_types(
    alphas=alphas,
    measuring_types=[MeasuringTypes.SAMPLING]
)
# Out:
# [CSD] 0.0.1|DEBUG|2021-10-16 06:22:51]: Executing One Layer circuit with Backend: fock,  with measuring_type: sampling and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-16 06:22:51]: Optimizing for alpha: 0.05
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: _execute_for_one_alpha, took: 18 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: Optimized for alpha: 0.05 beta: -1.1292187968676647e-06
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:10]: Optimizing for alpha: 0.7
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: _execute_for_one_alpha, took: 34 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: Optimized for alpha: 0.7 beta: -7.77839472653611e-05
# [CSD] 0.0.1|DEBUG|2021-10-16 06:23:44]: Optimizing for alpha: 1.1
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: _execute_for_one_alpha, took: 40 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Optimized for alpha: 1.1 beta: -4.6636522620090635e-08
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: execute, took: 1 minute and 33 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Executing One Layer circuit with Backend: gaussian,  with measuring_type: sampling and cutoff_dim: 10
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:24]: Optimizing for alpha: 0.05
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: _execute_for_one_alpha, took: 3 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: Optimized for alpha: 0.05 beta: 0.0
# [CSD] 0.0.1|DEBUG|2021-10-16 06:24:28]: Optimizing for alpha: 0.7
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: _execute_for_one_alpha, took: 1 minute and 38 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: Optimized for alpha: 0.7 beta: -3.113996399150598e-07
# [CSD] 0.0.1|DEBUG|2021-10-16 06:26:06]: Optimizing for alpha: 1.1
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# /home/asolana/anaconda3/envs/haqathon_test/lib/python3.9/site-packages/strawberryfields/backends/gaussianbackend/backend.py:215: UserWarning: Cannot simulate non-Gaussian states. Conditional state after Fock measurement has not been updated.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: _execute_for_one_alpha, took: 1 minute and 51 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: Optimized for alpha: 1.1 beta: 0.0
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: execute, took: 3 minutes and 33 seconds.
# [CSD] 0.0.1|DEBUG|2021-10-16 06:27:58]: execute_all_backends_and_measuring_types, took: 5 minutes and 7 seconds.

# %%
csd.plot_success_probabilities(measuring_types=[MeasuringTypes.SAMPLING])
